# %% [markdown]
# <a href="https://colab.research.google.com/github/dennnfrancisco/cafeingenieroinformatico/blob/main/Cafe_POS_and_Database_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cafe Ingeniero Informatico
# ##Point of Sale and Database System
#
# MALVARD Ingenieros <br>
# Group 3 BS CpE 3-3

# %% [markdown]
# **Login Page**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;


import java.sql.*;
import javax.swing.JOptionPane;
/**
 *
 * 
 */
public class LoginPage extends javax.swing.JFrame {

    /**
     * Creates new form Start
     */
        
    public LoginPage() {
        initComponents();
    }

    String username="";
    String password;
    
    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jPanel1 = new javax.swing.JPanel();
        jButton1 = new javax.swing.JButton();
        edtUsername = new javax.swing.JTextField();
        CashierLogin = new javax.swing.JLabel();
        jLabel2 = new javax.swing.JLabel();
        edtPassword = new javax.swing.JPasswordField();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);
        setTitle("Cafe Ingeniero Informatico Cashier Login");
        setBackground(new java.awt.Color(255, 255, 255));
        setCursor(new java.awt.Cursor(java.awt.Cursor.DEFAULT_CURSOR));
        setFont(new java.awt.Font("Montserrat", 0, 10)); // NOI18N
        setForeground(java.awt.Color.white);
        setName("Login"); // NOI18N
        setPreferredSize(new java.awt.Dimension(1090, 785));

        jPanel1.setBackground(new java.awt.Color(255, 255, 255));
        jPanel1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(142, 66, 56), 5, true));
        jPanel1.setPreferredSize(new java.awt.Dimension(1075, 745));

        jButton1.setBackground(new java.awt.Color(142, 56, 66));
        jButton1.setFont(new java.awt.Font("Montserrat", 0, 30)); // NOI18N
        jButton1.setForeground(new java.awt.Color(255, 255, 255));
        jButton1.setText("Login");
        jButton1.setBorder(javax.swing.BorderFactory.createLineBorder(new java.awt.Color(0, 0, 0)));
        jButton1.setBorderPainted(false);
        jButton1.setName("LoginButton"); // NOI18N
        jButton1.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton1ActionPerformed(evt);
            }
        });

        edtUsername.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        edtUsername.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Admin ID", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        edtUsername.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                edtUsernameActionPerformed(evt);
            }
        });

        CashierLogin.setFont(new java.awt.Font("Montserrat", 0, 40)); // NOI18N
        CashierLogin.setText("Cashier Login");

        jLabel2.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/logo-med.png"))); // NOI18N

        edtPassword.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        edtPassword.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Password", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        edtPassword.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                edtPasswordActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(357, 357, 357)
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING, false)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(38, 38, 38)
                        .addComponent(CashierLogin))
                    .addComponent(edtUsername, javax.swing.GroupLayout.DEFAULT_SIZE, 370, Short.MAX_VALUE)
                    .addComponent(jLabel2)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(45, 45, 45)
                        .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 273, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addComponent(edtPassword))
                .addContainerGap(323, Short.MAX_VALUE))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(41, 41, 41)
                .addComponent(jLabel2, javax.swing.GroupLayout.PREFERRED_SIZE, 344, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(CashierLogin)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(edtUsername, javax.swing.GroupLayout.PREFERRED_SIZE, 50, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(edtPassword, javax.swing.GroupLayout.PREFERRED_SIZE, 49, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 68, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(85, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, 1060, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, 725, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        pack();
    }// </editor-fold>                        

    private void edtUsernameActionPerformed(java.awt.event.ActionEvent evt) {                                            
        // TODO add your handling code here:
    }                                           

    private void jButton1ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        
        try{
            Class.forName("com.mysql.jdbc.Driver");
            Connection cn = DriverManager.getConnection("jdbc:mysql://remotemysql.com:3306/SlroZZ8W9B","SlroZZ8W9B","xEvUdzqfTW");
            
            username = edtUsername.getText();
            password = edtPassword.getText();
            
            Statement stm = cn.createStatement();
            
            String sql = "select * from login where username='"+username+"' and Password='"+password+"'";
            ResultSet rs = stm.executeQuery(sql);
            if(rs.next()){                
                new MainMenu(username).setVisible(true);
                dispose();
            }
            else{
                JOptionPane.showMessageDialog(this, "Admin ID or Password is invalid");
                edtUsername.setText("");
                edtPassword.setText("");
            }
            
            cn.close();
            
        }catch(Exception e){
            
            System.out.println(e.getMessage());
            
        }
        
        
        
        
    }                                        

    private void edtPasswordActionPerformed(java.awt.event.ActionEvent evt) {                                            
        // TODO add your handling code here:
    }                                           

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(LoginPage.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(LoginPage.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(LoginPage.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(LoginPage.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new LoginPage().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JLabel CashierLogin;
    private javax.swing.JPasswordField edtPassword;
    private javax.swing.JTextField edtUsername;
    private javax.swing.JButton jButton1;
    private javax.swing.JLabel jLabel2;
    private javax.swing.JPanel jPanel1;
    // End of variables declaration                   
}

# %% [markdown]
# **Main Menu**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

/**
 *
 * 
 */
public class MainMenu extends javax.swing.JFrame {

    /**
     * Creates new form MainMenu
     */
    String crewName;
    
    public MainMenu() {
        initComponents();
    }
    
    public MainMenu(String crewInCharge) {
        initComponents();
        
        crewName = crewInCharge;
    }

    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jPanel1 = new javax.swing.JPanel();
        jLabel1 = new javax.swing.JLabel();
        orderPageBtn = new javax.swing.JButton();
        custInfoBtn = new javax.swing.JButton();
        logoutBtn = new javax.swing.JButton();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);
        setResizable(false);

        jPanel1.setBackground(new java.awt.Color(255, 255, 255));
        jPanel1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 5, true));

        jLabel1.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/logo-med.png"))); // NOI18N

        orderPageBtn.setBackground(new java.awt.Color(144, 56, 66));
        orderPageBtn.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        orderPageBtn.setForeground(new java.awt.Color(255, 255, 255));
        orderPageBtn.setText("Continue to Order Page");
        orderPageBtn.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));
        orderPageBtn.setBorderPainted(false);
        orderPageBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                orderPageBtnActionPerformed(evt);
            }
        });

        custInfoBtn.setBackground(new java.awt.Color(144, 56, 66));
        custInfoBtn.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        custInfoBtn.setForeground(new java.awt.Color(255, 255, 255));
        custInfoBtn.setText("Fill Out Customer Contact Information Form");
        custInfoBtn.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));
        custInfoBtn.setBorderPainted(false);
        custInfoBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                custInfoBtnActionPerformed(evt);
            }
        });

        logoutBtn.setBackground(new java.awt.Color(144, 56, 66));
        logoutBtn.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        logoutBtn.setForeground(new java.awt.Color(255, 255, 255));
        logoutBtn.setText("Log Out");
        logoutBtn.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));
        logoutBtn.setBorderPainted(false);
        logoutBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                logoutBtnActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(jLabel1)
                .addGap(349, 349, 349))
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(231, 231, 231)
                        .addComponent(orderPageBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 588, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(383, 383, 383)
                        .addComponent(logoutBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 282, javax.swing.GroupLayout.PREFERRED_SIZE)))
                .addContainerGap(241, Short.MAX_VALUE))
            .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jPanel1Layout.createSequentialGroup()
                    .addGap(231, 231, 231)
                    .addComponent(custInfoBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 588, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addContainerGap(241, Short.MAX_VALUE)))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(48, 48, 48)
                .addComponent(jLabel1)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, 155, Short.MAX_VALUE)
                .addComponent(orderPageBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 96, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(31, 31, 31)
                .addComponent(logoutBtn)
                .addGap(28, 28, 28))
            .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                    .addContainerGap(432, Short.MAX_VALUE)
                    .addComponent(custInfoBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 96, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addGap(225, 225, 225)))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addContainerGap())
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addContainerGap())
        );

        pack();
    }// </editor-fold>                        

    private void orderPageBtnActionPerformed(java.awt.event.ActionEvent evt) {                                             
        new MenuPageTabbed(crewName).setVisible(true);
        dispose();
    }                                            

    private void custInfoBtnActionPerformed(java.awt.event.ActionEvent evt) {                                            
        new CustomerInfo(crewName).setVisible(true);
        dispose();
    }                                           

    private void logoutBtnActionPerformed(java.awt.event.ActionEvent evt) {                                          
        new LoginPage().setVisible(true);
        dispose();
    }                                         

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(MainMenu.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(MainMenu.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(MainMenu.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(MainMenu.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new MainMenu().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JButton custInfoBtn;
    private javax.swing.JLabel jLabel1;
    private javax.swing.JPanel jPanel1;
    private javax.swing.JButton logoutBtn;
    private javax.swing.JButton orderPageBtn;
    // End of variables declaration                   
}

# %% [markdown]
# **Costumer Information for Contact Tracing**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

import java.sql.*;
import javax.swing.JOptionPane;


/**
 *
 * 
 */
public class CustomerInfo extends javax.swing.JFrame {

    /**
     * Creates new form CustomerInfo
     */
    String crewName;
    
    public CustomerInfo() {
        initComponents();
    }
    
    public CustomerInfo(String crewInCharge) {
        initComponents();
        
        crewName = crewInCharge;
    }

    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        buttonGroup1 = new javax.swing.ButtonGroup();
        buttonGroup2 = new javax.swing.ButtonGroup();
        buttonGroup3 = new javax.swing.ButtonGroup();
        jPanel1 = new javax.swing.JPanel();
        jLabel1 = new javax.swing.JLabel();
        jLabel2 = new javax.swing.JLabel();
        cxEA = new javax.swing.JTextField();
        cxCN = new javax.swing.JTextField();
        cxAddress = new javax.swing.JTextField();
        cxName = new javax.swing.JTextField();
        jPanel2 = new javax.swing.JPanel();
        jLabel3 = new javax.swing.JLabel();
        jLabel7 = new javax.swing.JLabel();
        jLabel8 = new javax.swing.JLabel();
        jLabel9 = new javax.swing.JLabel();
        jLabel10 = new javax.swing.JLabel();
        jLabel11 = new javax.swing.JLabel();
        jLabel12 = new javax.swing.JLabel();
        sFever = new javax.swing.JCheckBox();
        sCough = new javax.swing.JCheckBox();
        sHeadache = new javax.swing.JCheckBox();
        sRunnyNose = new javax.swing.JCheckBox();
        sSoreThroat = new javax.swing.JCheckBox();
        sLossOfSnT = new javax.swing.JCheckBox();
        sNone = new javax.swing.JCheckBox();
        jPanel3 = new javax.swing.JPanel();
        jLabel4 = new javax.swing.JLabel();
        jLabel5 = new javax.swing.JLabel();
        cxTemp = new javax.swing.JTextField();
        yesTravel = new javax.swing.JRadioButton();
        noTravel = new javax.swing.JRadioButton();
        yesExp = new javax.swing.JRadioButton();
        noExp = new javax.swing.JRadioButton();
        submitCXBtn = new javax.swing.JButton();
        dataPrivMsgBtn = new javax.swing.JButton();
        backCXBtn = new javax.swing.JButton();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);
        setTitle("Cafe Ingeniero Informatico Customer Contact Information Form");
        setResizable(false);

        jPanel1.setBackground(new java.awt.Color(255, 255, 255));
        jPanel1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(142, 66, 56), 5, true));

        jLabel1.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/logo-small.png"))); // NOI18N

        jLabel2.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jLabel2.setText("Customer Contact Information");

        cxEA.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        cxEA.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Email Address", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        cxEA.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cxEAActionPerformed(evt);
            }
        });

        cxCN.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        cxCN.setToolTipText("");
        cxCN.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Contact Number", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        cxCN.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cxCNActionPerformed(evt);
            }
        });
        cxCN.addKeyListener(new java.awt.event.KeyAdapter() {
            public void keyTyped(java.awt.event.KeyEvent evt) {
                cxCNKeyTyped(evt);
            }
        });

        cxAddress.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        cxAddress.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Address", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        cxAddress.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cxAddressActionPerformed(evt);
            }
        });
        cxAddress.addKeyListener(new java.awt.event.KeyAdapter() {
            public void keyTyped(java.awt.event.KeyEvent evt) {
                cxAddressKeyTyped(evt);
            }
        });

        cxName.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        cxName.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true), "Name", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        cxName.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cxNameActionPerformed(evt);
            }
        });

        jPanel2.setBackground(new java.awt.Color(255, 255, 255));
        jPanel2.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true));

        jLabel3.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        jLabel3.setText("Have they experienced any of the following for the past 14 days?");

        jLabel7.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel7.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/headache.png"))); // NOI18N
        jLabel7.setToolTipText("");

        jLabel8.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel8.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/fever.png"))); // NOI18N
        jLabel8.setToolTipText("");

        jLabel9.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel9.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/cough.png"))); // NOI18N
        jLabel9.setToolTipText("");

        jLabel10.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel10.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/sneeze.png"))); // NOI18N
        jLabel10.setToolTipText("");

        jLabel11.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel11.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/sore-throat.png"))); // NOI18N
        jLabel11.setToolTipText("");

        jLabel12.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel12.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/symptoms/loss-of-sense-of-smell.png"))); // NOI18N
        jLabel12.setToolTipText("");

        sFever.setBackground(new java.awt.Color(255, 255, 255));
        sFever.setText("Fever");
        sFever.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sFeverActionPerformed(evt);
            }
        });

        sCough.setBackground(new java.awt.Color(255, 255, 255));
        sCough.setText("Cough");
        sCough.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sCoughActionPerformed(evt);
            }
        });

        sHeadache.setBackground(new java.awt.Color(255, 255, 255));
        sHeadache.setText("Headache");
        sHeadache.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sHeadacheActionPerformed(evt);
            }
        });

        sRunnyNose.setBackground(new java.awt.Color(255, 255, 255));
        sRunnyNose.setText("Runny Nose");
        sRunnyNose.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sRunnyNoseActionPerformed(evt);
            }
        });

        sSoreThroat.setBackground(new java.awt.Color(255, 255, 255));
        sSoreThroat.setText("Sore Throat");
        sSoreThroat.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sSoreThroatActionPerformed(evt);
            }
        });

        sLossOfSnT.setBackground(new java.awt.Color(255, 255, 255));
        sLossOfSnT.setText("Loss of sense of smell and/or taste");
        sLossOfSnT.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sLossOfSnTActionPerformed(evt);
            }
        });

        sNone.setBackground(new java.awt.Color(255, 255, 255));
        sNone.setText("None");
        sNone.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                sNoneActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel2Layout = new javax.swing.GroupLayout(jPanel2);
        jPanel2.setLayout(jPanel2Layout);
        jPanel2Layout.setHorizontalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel2Layout.createSequentialGroup()
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(sNone)
                .addGap(18, 18, 18)
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jLabel8, javax.swing.GroupLayout.PREFERRED_SIZE, 55, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(sFever))
                .addGap(31, 31, 31)
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jLabel9)
                    .addComponent(sCough))
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(32, 32, 32)
                        .addComponent(jLabel7))
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(18, 18, 18)
                        .addComponent(sHeadache)))
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(57, 57, 57)
                        .addComponent(jLabel10))
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(41, 41, 41)
                        .addComponent(sRunnyNose)))
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(52, 52, 52)
                        .addComponent(jLabel11)
                        .addGap(117, 117, 117)
                        .addComponent(jLabel12))
                    .addGroup(jPanel2Layout.createSequentialGroup()
                        .addGap(37, 37, 37)
                        .addComponent(sSoreThroat)
                        .addGap(39, 39, 39)
                        .addComponent(sLossOfSnT)))
                .addGap(44, 44, 44))
            .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jPanel2Layout.createSequentialGroup()
                    .addContainerGap()
                    .addComponent(jLabel3)
                    .addContainerGap(274, Short.MAX_VALUE)))
        );
        jPanel2Layout.setVerticalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel2Layout.createSequentialGroup()
                .addContainerGap(47, Short.MAX_VALUE)
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jLabel7, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jLabel8, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jLabel9, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jLabel10, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jLabel11, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jLabel12, javax.swing.GroupLayout.PREFERRED_SIZE, 53, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(sFever)
                        .addComponent(sNone))
                    .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(sCough)
                        .addComponent(sHeadache))
                    .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(sRunnyNose)
                        .addComponent(sSoreThroat))
                    .addComponent(sLossOfSnT))
                .addGap(11, 11, 11))
            .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jPanel2Layout.createSequentialGroup()
                    .addGap(13, 13, 13)
                    .addComponent(jLabel3)
                    .addContainerGap(104, Short.MAX_VALUE)))
        );

        jPanel3.setBackground(new java.awt.Color(255, 255, 255));
        jPanel3.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true));

        jLabel4.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        jLabel4.setText("Have they visited or travelled outside of the country within the last 14 days?");

        jLabel5.setFont(new java.awt.Font("Montserrat", 0, 14)); // NOI18N
        jLabel5.setText("In the last 14 days, have they been in close contact or exposed to any person suspected of or confirmed with COVID-19?");

        cxTemp.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        cxTemp.setHorizontalAlignment(javax.swing.JTextField.CENTER);
        cxTemp.setBorder(javax.swing.BorderFactory.createTitledBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true), "Temperature Reading of the Customer", javax.swing.border.TitledBorder.DEFAULT_JUSTIFICATION, javax.swing.border.TitledBorder.DEFAULT_POSITION, new java.awt.Font("Montserrat", 0, 11))); // NOI18N
        cxTemp.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cxTempActionPerformed(evt);
            }
        });
        cxTemp.addKeyListener(new java.awt.event.KeyAdapter() {
            public void keyTyped(java.awt.event.KeyEvent evt) {
                cxTempKeyTyped(evt);
            }
        });

        buttonGroup2.add(yesTravel);
        yesTravel.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        yesTravel.setText("Yes");
        yesTravel.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                yesTravelActionPerformed(evt);
            }
        });

        buttonGroup2.add(noTravel);
        noTravel.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        noTravel.setText("No");
        noTravel.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                noTravelActionPerformed(evt);
            }
        });

        buttonGroup3.add(yesExp);
        yesExp.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        yesExp.setText("Yes");

        buttonGroup3.add(noExp);
        noExp.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        noExp.setText("No");
        noExp.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                noExpActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel3Layout = new javax.swing.GroupLayout(jPanel3);
        jPanel3.setLayout(jPanel3Layout);
        jPanel3Layout.setHorizontalGroup(
            jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel3Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jLabel5)
                    .addGroup(jPanel3Layout.createSequentialGroup()
                        .addComponent(jLabel4)
                        .addGap(18, 18, 18)
                        .addComponent(yesTravel)
                        .addGap(8, 8, 8)
                        .addComponent(noTravel))
                    .addGroup(jPanel3Layout.createSequentialGroup()
                        .addGap(10, 10, 10)
                        .addComponent(yesExp)
                        .addGap(8, 8, 8)
                        .addComponent(noExp))
                    .addComponent(cxTemp, javax.swing.GroupLayout.PREFERRED_SIZE, 230, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel3Layout.setVerticalGroup(
            jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel3Layout.createSequentialGroup()
                .addGap(16, 16, 16)
                .addGroup(jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                    .addComponent(jLabel4, javax.swing.GroupLayout.PREFERRED_SIZE, 18, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(yesTravel)
                    .addComponent(noTravel))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jLabel5, javax.swing.GroupLayout.PREFERRED_SIZE, 18, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addGroup(jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                    .addComponent(yesExp)
                    .addComponent(noExp))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addComponent(cxTemp)
                .addContainerGap())
        );

        submitCXBtn.setBackground(new java.awt.Color(144, 56, 66));
        submitCXBtn.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        submitCXBtn.setForeground(new java.awt.Color(255, 255, 255));
        submitCXBtn.setText("Submit");
        submitCXBtn.setBorderPainted(false);
        submitCXBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                submitCXBtnActionPerformed(evt);
            }
        });

        dataPrivMsgBtn.setBackground(new java.awt.Color(144, 56, 66));
        dataPrivMsgBtn.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        dataPrivMsgBtn.setForeground(new java.awt.Color(255, 255, 255));
        dataPrivMsgBtn.setText("COVID-19 Warning and Data Collection");
        dataPrivMsgBtn.setBorderPainted(false);
        dataPrivMsgBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                dataPrivMsgBtnActionPerformed(evt);
            }
        });

        backCXBtn.setBackground(new java.awt.Color(144, 56, 66));
        backCXBtn.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        backCXBtn.setForeground(new java.awt.Color(255, 255, 255));
        backCXBtn.setText("Back");
        backCXBtn.setBorderPainted(false);
        backCXBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                backCXBtnActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.TRAILING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addComponent(dataPrivMsgBtn)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                        .addComponent(submitCXBtn)
                        .addGap(247, 247, 247)
                        .addComponent(backCXBtn))
                    .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING, false)
                        .addComponent(jPanel2, javax.swing.GroupLayout.Alignment.TRAILING, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                        .addComponent(cxEA, javax.swing.GroupLayout.Alignment.TRAILING)
                        .addComponent(cxCN, javax.swing.GroupLayout.Alignment.TRAILING)
                        .addComponent(cxAddress, javax.swing.GroupLayout.Alignment.TRAILING)
                        .addComponent(cxName)
                        .addComponent(jPanel3, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                        .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                            .addGap(295, 295, 295)
                            .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                                .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                                    .addComponent(jLabel1)
                                    .addGap(410, 410, 410))
                                .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                                    .addComponent(jLabel2)
                                    .addGap(283, 283, 283))))))
                .addGap(12, 12, 12))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addComponent(jLabel1, javax.swing.GroupLayout.PREFERRED_SIZE, 121, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(4, 4, 4)
                .addComponent(jLabel2)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(cxName, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(cxAddress, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(3, 3, 3)
                .addComponent(cxCN, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(cxEA, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jPanel2, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addComponent(jPanel3, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(18, 18, 18)
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                    .addComponent(submitCXBtn)
                    .addComponent(dataPrivMsgBtn)
                    .addComponent(backCXBtn))
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        pack();
    }// </editor-fold>                        

    private void cxEAActionPerformed(java.awt.event.ActionEvent evt) {                                     
        // TODO add your handling code here:
    }                                    

    private void cxCNActionPerformed(java.awt.event.ActionEvent evt) {                                     
        // TODO add your handling code here:
    }                                    

    private void cxAddressActionPerformed(java.awt.event.ActionEvent evt) {                                          
        // TODO add your handling code here:
    }                                         

    private void cxNameActionPerformed(java.awt.event.ActionEvent evt) {                                       
        // TODO add your handling code here:
    }                                      

    private void noTravelActionPerformed(java.awt.event.ActionEvent evt) {                                         
        // TODO add your handling code here:
    }                                        

    private void noExpActionPerformed(java.awt.event.ActionEvent evt) {                                      
        // TODO add your handling code here:
    }                                     

    private void cxTempActionPerformed(java.awt.event.ActionEvent evt) {                                       
        
    }                                      

    private void dataPrivMsgBtnActionPerformed(java.awt.event.ActionEvent evt) {                                               
        new COVID19Warning().setVisible(true);
    }                                              

    private void submitCXBtnActionPerformed(java.awt.event.ActionEvent evt) {                                            
        
        
        
        if(cxName.getText().equals("") || cxAddress.getText().equals("") || cxCN.getText().equals("") || cxEA.getText().equals("") || cxTemp.getText().equals("")){
            JOptionPane.showMessageDialog(this, "Fill all necessary fields");
        }
        
        else if(!sNone.isSelected() && !sFever.isSelected() && !sCough.isSelected() && !sHeadache.isSelected() && !sRunnyNose.isSelected() && !sSoreThroat.isSelected() && !sLossOfSnT.isSelected()){
            JOptionPane.showMessageDialog(this, "Fill all necessary fields");
        }
        
        else if(!yesTravel.isSelected() && !noTravel.isSelected()){
            JOptionPane.showMessageDialog(this, "Fill all necessary fields");
        }
        
        else if(!yesExp.isSelected() && !noExp.isSelected()){
            JOptionPane.showMessageDialog(this, "Fill all necessary fields");
        }

        else{
            
            double cxTempDouble = Double.parseDouble(cxTemp.getText());
            
            if(cxTempDouble < 32 || cxTempDouble > 42 || cxCN.getText().length()<=9){
                
                if(cxTempDouble < 32 || cxTempDouble > 42){
                    JOptionPane.showMessageDialog(this, "Enter valid body temperature value");
                    cxTemp.setText("");
                }
                
                if(cxCN.getText().length()<=9){
                    JOptionPane.showMessageDialog(this, "Enter valid contact number");
                    cxCN.setText("");
                }    
            }
            
            else{
        
                try{
                    Class.forName("com.mysql.jdbc.Driver");
                    Connection cn = DriverManager.getConnection("jdbc:mysql://remotemysql.com:3306/SlroZZ8W9B","SlroZZ8W9B","xEvUdzqfTW");

                    String query="insert into customerdata(customerName, customerAddress, customerCN, customerEA, customerSymptoms, customerTravelHist, customerExposure, customerTemp) values(?,?,?,?,?,?,?,?)";
                    PreparedStatement MyPst=cn.prepareStatement(query);
                    MyPst.setString(1, cxName.getText());
                    MyPst.setString(2, cxAddress.getText());

                    long cCN = Long.parseLong(cxCN.getText());

                    MyPst.setLong(3,cCN);

                    MyPst.setString(4, cxEA.getText());

                    String cxSymptoms = "";

                    if(sNone.isSelected()){
                        cxSymptoms+=sNone.getText()+" ";
                    }            
                    if(sFever.isSelected()){
                        cxSymptoms+=sFever.getText()+" ";
                    }            
                    if(sCough.isSelected()){
                        cxSymptoms+=sCough.getText()+" ";
                    }            
                    if(sHeadache.isSelected()){
                        cxSymptoms+=sHeadache.getText()+" ";
                    }            
                    if(sRunnyNose.isSelected()){
                        cxSymptoms+=sRunnyNose.getText()+" ";
                    }            
                    if(sSoreThroat.isSelected()){
                        cxSymptoms+=sSoreThroat.getText()+" ";
                    }            
                    if(sLossOfSnT.isSelected()){
                        cxSymptoms+=sLossOfSnT.getText()+" ";
                    }


                    MyPst.setString(5, cxSymptoms);

                    String cxTravelHist = "";

                    if(yesTravel.isSelected()){
                        cxTravelHist = "Yes";
                    }            
                    if(noTravel.isSelected()){
                        cxTravelHist = "No";
                    }

                    MyPst.setString(6, cxTravelHist);

                    String cxExp = "";            
                    if(yesExp.isSelected()){
                        cxExp = "Yes";
                    }            
                    if(noExp.isSelected()){
                        cxExp = "No";
                    }

                    MyPst.setString(7, cxExp);            
                    MyPst.setString(8, cxTemp.getText());


                    MyPst.execute();
                    MyPst.close();
                    cxName.setText("");
                    cxAddress.setText("");
                    cxCN.setText("");
                    cxEA.setText("");
                    cxTemp.setText("");
                    sNone.setSelected(false);
                    sFever.setSelected(false);
                    sCough.setSelected(false);
                    sHeadache.setSelected(false);
                    sRunnyNose.setSelected(false);
                    sSoreThroat.setSelected(false);
                    sLossOfSnT.setSelected(false);
                    buttonGroup2.clearSelection();
                    buttonGroup3.clearSelection();

                    cn.close();

                }catch(Exception e){            
                    System.out.println(e.getMessage());            
                }

                new MainMenu(crewName).setVisible(true);
                dispose();
            }
        }
        
    }                                           

    private void sFeverActionPerformed(java.awt.event.ActionEvent evt) {                                       
        sNone.setSelected(false);
    }                                      

    private void sHeadacheActionPerformed(java.awt.event.ActionEvent evt) {                                          
        sNone.setSelected(false);
    }                                         

    private void sNoneActionPerformed(java.awt.event.ActionEvent evt) {                                      
        sFever.setSelected(false);
        sCough.setSelected(false);
        sHeadache.setSelected(false);
        sRunnyNose.setSelected(false);
        sSoreThroat.setSelected(false);
        sLossOfSnT.setSelected(false);
    }                                     

    private void sCoughActionPerformed(java.awt.event.ActionEvent evt) {                                       
        sNone.setSelected(false);
    }                                      

    private void sRunnyNoseActionPerformed(java.awt.event.ActionEvent evt) {                                           
        sNone.setSelected(false);
    }                                          

    private void sSoreThroatActionPerformed(java.awt.event.ActionEvent evt) {                                            
        sNone.setSelected(false);
    }                                           

    private void sLossOfSnTActionPerformed(java.awt.event.ActionEvent evt) {                                           
        sNone.setSelected(false);
    }                                          

    private void yesTravelActionPerformed(java.awt.event.ActionEvent evt) {                                          
        // TODO add your handling code here:
    }                                         

    private void cxAddressKeyTyped(java.awt.event.KeyEvent evt) {                                   
        // TODO add your handling code here:
    }                                  

    private void cxCNKeyTyped(java.awt.event.KeyEvent evt) {                              
        char c = evt.getKeyChar();
        
        if(!Character.isDigit(c)){
            evt.consume();
        }
        
        if (cxCN.getText().trim().length() == 10 || evt.getKeyChar() == java.awt.event.KeyEvent.VK_BACK_SPACE) {
            evt.consume();
        } 
    }                             

    private void cxTempKeyTyped(java.awt.event.KeyEvent evt) {                                
        if(Character.isLetter(evt.getKeyChar())){
            evt.consume();
        }
        else{
            try{
                Double.parseDouble(cxTemp.getText()+evt.getKeyChar());
            }catch(NumberFormatException e){
                evt.consume();
            }
        }
    }                               

    private void backCXBtnActionPerformed(java.awt.event.ActionEvent evt) {                                          
        new MainMenu(crewName).setVisible(true);
        dispose();
    }                                         

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(CustomerInfo.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(CustomerInfo.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(CustomerInfo.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(CustomerInfo.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new CustomerInfo().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JButton backCXBtn;
    private javax.swing.ButtonGroup buttonGroup1;
    private javax.swing.ButtonGroup buttonGroup2;
    private javax.swing.ButtonGroup buttonGroup3;
    private javax.swing.JTextField cxAddress;
    private javax.swing.JTextField cxCN;
    private javax.swing.JTextField cxEA;
    private javax.swing.JTextField cxName;
    private javax.swing.JTextField cxTemp;
    private javax.swing.JButton dataPrivMsgBtn;
    private javax.swing.JLabel jLabel1;
    private javax.swing.JLabel jLabel10;
    private javax.swing.JLabel jLabel11;
    private javax.swing.JLabel jLabel12;
    private javax.swing.JLabel jLabel2;
    private javax.swing.JLabel jLabel3;
    private javax.swing.JLabel jLabel4;
    private javax.swing.JLabel jLabel5;
    private javax.swing.JLabel jLabel7;
    private javax.swing.JLabel jLabel8;
    private javax.swing.JLabel jLabel9;
    private javax.swing.JPanel jPanel1;
    private javax.swing.JPanel jPanel2;
    private javax.swing.JPanel jPanel3;
    private javax.swing.JRadioButton noExp;
    private javax.swing.JRadioButton noTravel;
    private javax.swing.JCheckBox sCough;
    private javax.swing.JCheckBox sFever;
    private javax.swing.JCheckBox sHeadache;
    private javax.swing.JCheckBox sLossOfSnT;
    private javax.swing.JCheckBox sNone;
    private javax.swing.JCheckBox sRunnyNose;
    private javax.swing.JCheckBox sSoreThroat;
    private javax.swing.JButton submitCXBtn;
    private javax.swing.JRadioButton yesExp;
    private javax.swing.JRadioButton yesTravel;
    // End of variables declaration                   
}

# %% [markdown]
# **COVID-19 Warning**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

/**
 *
 * 
 */
public class COVID19Warning extends javax.swing.JFrame {

    /**
     * Creates new form COVID19Warning
     */
    public COVID19Warning() {
        initComponents();
    }

    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jPanel1 = new javax.swing.JPanel();
        jLabel1 = new javax.swing.JLabel();
        backWarning = new javax.swing.JButton();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);

        jPanel1.setBackground(new java.awt.Color(207, 189, 187));

        jLabel1.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/covid-19-small.png"))); // NOI18N

        backWarning.setText("Back");
        backWarning.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                backWarningActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jLabel1)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(347, 347, 347)
                .addComponent(backWarning))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addComponent(jLabel1)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(backWarning)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
        );

        pack();
    }// </editor-fold>                        

    private void backWarningActionPerformed(java.awt.event.ActionEvent evt) {                                            
        dispose();
    }                                           

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(COVID19Warning.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(COVID19Warning.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(COVID19Warning.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(COVID19Warning.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new COVID19Warning().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JButton backWarning;
    private javax.swing.JLabel jLabel1;
    private javax.swing.JPanel jPanel1;
    // End of variables declaration                   
}

# %% [markdown]
# **Tabbed Menu Page**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

import java.sql.*;
import javax.swing.JOptionPane;
import javax.swing.table.DefaultTableModel;

/**
 *
 * 
 */
public class MenuPageTabbed extends javax.swing.JFrame{

    /**
     * Creates new form MenuPage
     */
    String crewName;
    
    public MenuPageTabbed() {
        initComponents();
        
    }
    
    public MenuPageTabbed(String crewInCharge) {
        initComponents();
        
        crewName = crewInCharge;
        greetingLabel.setText("Hi! I'm "+crewName+". May I take your order?");
        
        try{
            Class.forName("com.mysql.jdbc.Driver");
            Connection cn = DriverManager.getConnection("jdbc:mysql://remotemysql.com:3306/SlroZZ8W9B","SlroZZ8W9B","xEvUdzqfTW");
                        
            Statement stm = cn.createStatement();
            
            String sql = "select * from ordertable";
            ResultSet rs = stm.executeQuery(sql);
            while(rs.next()){  
                
                String orderNum = String.valueOf(rs.getInt("orderID")+1);
                
                jLabel4.setText("Order #: "+orderNum);

            }
            
            cn.close();
            
        }catch(Exception e){
            
            System.out.println(e.getMessage());
            
        }
          
    }
       
    
    int totalAmountDue;
    int updateLSLock=0;
    int updateLMLock=0;
    int updateLLLock=0;
    int updateCCSLock=0;
    int updateCCMLock=0;
    int updateCCLLock=0;
    int updateBBSLock=0;
    int updateBBMLock=0;
    int updateBBLLock=0;
    int updateSCSLock=0;
    int updateSCMLock=0;
    int updateSCLLock=0;
    
    
    
    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jLayeredPane3 = new javax.swing.JLayeredPane();
        buttonGroup1 = new javax.swing.ButtonGroup();
        buttonGroup2 = new javax.swing.ButtonGroup();
        buttonGroup3 = new javax.swing.ButtonGroup();
        buttonGroup4 = new javax.swing.ButtonGroup();
        jPanel6 = new javax.swing.JPanel();
        Logo = new javax.swing.JLabel();
        jPanel1 = new javax.swing.JPanel();
        jLabel3 = new javax.swing.JLabel();
        jLabel4 = new javax.swing.JLabel();
        greetingLabel = new javax.swing.JLabel();
        jSeparator3 = new javax.swing.JSeparator();
        jPanel2 = new javax.swing.JPanel();
        jButton15 = new javax.swing.JButton();
        logoutBtn = new javax.swing.JButton();
        jPanel4 = new javax.swing.JPanel();
        jLabel1 = new javax.swing.JLabel();
        jLabel2 = new javax.swing.JLabel();
        jScrollPane1 = new javax.swing.JScrollPane();
        jTable1 = new javax.swing.JTable();
        jPanel3 = new javax.swing.JPanel();
        totalOrderPrice = new javax.swing.JLabel();
        deleteSelectedOrder = new javax.swing.JButton();
        jPanel5 = new javax.swing.JPanel();
        cashPay = new javax.swing.JButton();
        cardPay = new javax.swing.JButton();
        cancelOrder = new javax.swing.JButton();
        jTabbedPane1 = new javax.swing.JTabbedPane();
        jLayeredPane1 = new javax.swing.JLayeredPane();
        jPanel7 = new javax.swing.JPanel();
        jButton1 = new javax.swing.JButton();
        jButton2 = new javax.swing.JButton();
        jButton3 = new javax.swing.JButton();
        jButton4 = new javax.swing.JButton();
        jLayeredPane2 = new javax.swing.JLayeredPane();
        jPanel8 = new javax.swing.JPanel();
        jLabel7 = new javax.swing.JLabel();
        jPanel9 = new javax.swing.JPanel();
        jSpinner1 = new javax.swing.JSpinner();
        LatteSmall = new javax.swing.JRadioButton();
        LatteMedium = new javax.swing.JRadioButton();
        LatteLarge = new javax.swing.JRadioButton();
        jButton5 = new javax.swing.JButton();
        jLabel8 = new javax.swing.JLabel();
        jLayeredPane4 = new javax.swing.JLayeredPane();
        jPanel10 = new javax.swing.JPanel();
        jLabel9 = new javax.swing.JLabel();
        jPanel12 = new javax.swing.JPanel();
        jSpinner3 = new javax.swing.JSpinner();
        CcSmall = new javax.swing.JRadioButton();
        CcMedium = new javax.swing.JRadioButton();
        CcLarge = new javax.swing.JRadioButton();
        jButton7 = new javax.swing.JButton();
        jLabel11 = new javax.swing.JLabel();
        jLayeredPane5 = new javax.swing.JLayeredPane();
        jPanel13 = new javax.swing.JPanel();
        jLabel12 = new javax.swing.JLabel();
        jPanel14 = new javax.swing.JPanel();
        jSpinner4 = new javax.swing.JSpinner();
        BbSmall = new javax.swing.JRadioButton();
        BbMedium = new javax.swing.JRadioButton();
        BbLarge = new javax.swing.JRadioButton();
        jButton8 = new javax.swing.JButton();
        jLabel13 = new javax.swing.JLabel();
        jLayeredPane6 = new javax.swing.JLayeredPane();
        jPanel15 = new javax.swing.JPanel();
        jLabel14 = new javax.swing.JLabel();
        jPanel16 = new javax.swing.JPanel();
        jSpinner5 = new javax.swing.JSpinner();
        ScSmall = new javax.swing.JRadioButton();
        ScMedium = new javax.swing.JRadioButton();
        ScLarge = new javax.swing.JRadioButton();
        jButton9 = new javax.swing.JButton();
        jLabel15 = new javax.swing.JLabel();
        jMenuBar1 = new javax.swing.JMenuBar();

        javax.swing.GroupLayout jLayeredPane3Layout = new javax.swing.GroupLayout(jLayeredPane3);
        jLayeredPane3.setLayout(jLayeredPane3Layout);
        jLayeredPane3Layout.setHorizontalGroup(
            jLayeredPane3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 100, Short.MAX_VALUE)
        );
        jLayeredPane3Layout.setVerticalGroup(
            jLayeredPane3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 100, Short.MAX_VALUE)
        );

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);
        setResizable(false);

        jPanel6.setBackground(new java.awt.Color(255, 255, 255));
        jPanel6.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 5, true));

        Logo.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        Logo.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/logo-small.png"))); // NOI18N

        jPanel1.setBackground(new java.awt.Color(144, 56, 66));
        jPanel1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 3, true));
        jPanel1.setForeground(new java.awt.Color(255, 255, 255));
        jPanel1.setToolTipText("");
        jPanel1.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N

        jLabel3.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jLabel3.setForeground(new java.awt.Color(255, 255, 255));
        jLabel3.setText("Welcome to Cafe Ingeniero Informatico!");

        jLabel4.setFont(new java.awt.Font("Montserrat", 0, 20)); // NOI18N
        jLabel4.setForeground(new java.awt.Color(255, 255, 255));
        jLabel4.setText("Order no. ");

        greetingLabel.setFont(new java.awt.Font("Montserrat", 0, 20)); // NOI18N
        greetingLabel.setForeground(new java.awt.Color(255, 255, 255));
        greetingLabel.setText("Hi! I'm "+crewName);

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                            .addComponent(jSeparator3)
                            .addGroup(jPanel1Layout.createSequentialGroup()
                                .addComponent(jLabel4)
                                .addGap(0, 0, Short.MAX_VALUE)))
                        .addContainerGap())
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addComponent(greetingLabel)
                        .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))))
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(89, 89, 89)
                .addComponent(jLabel3)
                .addContainerGap(183, Short.MAX_VALUE))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(jLabel3)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, 8, Short.MAX_VALUE)
                .addComponent(jSeparator3, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(greetingLabel)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, 14, Short.MAX_VALUE)
                .addComponent(jLabel4)
                .addContainerGap())
        );

        jPanel2.setBackground(new java.awt.Color(255, 255, 255));

        jButton15.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/Buttons/Menu.png"))); // NOI18N
        jButton15.setBorderPainted(false);
        jButton15.setContentAreaFilled(false);
        jButton15.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton15ActionPerformed(evt);
            }
        });

        logoutBtn.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/Buttons/Logout.png"))); // NOI18N
        logoutBtn.setBorderPainted(false);
        logoutBtn.setContentAreaFilled(false);
        logoutBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                logoutBtnActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel2Layout = new javax.swing.GroupLayout(jPanel2);
        jPanel2.setLayout(jPanel2Layout);
        jPanel2Layout.setHorizontalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel2Layout.createSequentialGroup()
                .addGap(2, 2, 2)
                .addComponent(jButton15, javax.swing.GroupLayout.PREFERRED_SIZE, 115, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(18, 18, 18)
                .addComponent(logoutBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 115, javax.swing.GroupLayout.PREFERRED_SIZE))
        );
        jPanel2Layout.setVerticalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel2Layout.createSequentialGroup()
                .addGroup(jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jButton15, javax.swing.GroupLayout.PREFERRED_SIZE, 75, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(logoutBtn, javax.swing.GroupLayout.PREFERRED_SIZE, 75, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addGap(0, 11, Short.MAX_VALUE))
        );

        jPanel4.setBackground(new java.awt.Color(144, 56, 66));
        jPanel4.setBorder(javax.swing.BorderFactory.createBevelBorder(javax.swing.border.BevelBorder.RAISED, java.awt.Color.lightGray, java.awt.Color.lightGray, java.awt.Color.gray, java.awt.Color.gray));

        jLabel1.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jLabel1.setForeground(new java.awt.Color(255, 255, 255));
        jLabel1.setText("Bill");

        jLabel2.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jLabel2.setForeground(new java.awt.Color(255, 255, 255));
        jLabel2.setText("Total");

        jTable1.setModel(new javax.swing.table.DefaultTableModel(
            new Object [][] {

            },
            new String [] {
                "Item", "Quantity", "Price"
            }
        ));
        jTable1.addMouseListener(new java.awt.event.MouseAdapter() {
            public void mouseClicked(java.awt.event.MouseEvent evt) {
                jTable1MouseClicked(evt);
            }
        });
        jScrollPane1.setViewportView(jTable1);

        totalOrderPrice.setText("0");

        javax.swing.GroupLayout jPanel3Layout = new javax.swing.GroupLayout(jPanel3);
        jPanel3.setLayout(jPanel3Layout);
        jPanel3Layout.setHorizontalGroup(
            jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel3Layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(totalOrderPrice, javax.swing.GroupLayout.DEFAULT_SIZE, 122, Short.MAX_VALUE)
                .addContainerGap())
        );
        jPanel3Layout.setVerticalGroup(
            jPanel3Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(totalOrderPrice, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
        );

        deleteSelectedOrder.setText("Remove Selected Order");
        deleteSelectedOrder.setToolTipText("");
        deleteSelectedOrder.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                deleteSelectedOrderActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel4Layout = new javax.swing.GroupLayout(jPanel4);
        jPanel4.setLayout(jPanel4Layout);
        jPanel4Layout.setHorizontalGroup(
            jPanel4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel4Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jScrollPane1, javax.swing.GroupLayout.PREFERRED_SIZE, 0, Short.MAX_VALUE)
                    .addGroup(jPanel4Layout.createSequentialGroup()
                        .addComponent(jLabel2)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                        .addComponent(jPanel3, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addGroup(jPanel4Layout.createSequentialGroup()
                        .addComponent(jLabel1)
                        .addGap(0, 0, Short.MAX_VALUE))
                    .addComponent(deleteSelectedOrder, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
                .addContainerGap())
        );
        jPanel4Layout.setVerticalGroup(
            jPanel4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel4Layout.createSequentialGroup()
                .addContainerGap(15, Short.MAX_VALUE)
                .addComponent(jLabel1, javax.swing.GroupLayout.PREFERRED_SIZE, 30, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jScrollPane1, javax.swing.GroupLayout.PREFERRED_SIZE, 360, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(4, 4, 4)
                .addComponent(deleteSelectedOrder)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addGroup(jPanel4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING, false)
                    .addComponent(jPanel3, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                    .addComponent(jLabel2, javax.swing.GroupLayout.PREFERRED_SIZE, 30, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addContainerGap())
        );

        jPanel5.setBackground(new java.awt.Color(255, 255, 255));

        cashPay.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/Buttons/Cash.png"))); // NOI18N
        cashPay.setBorderPainted(false);
        cashPay.setContentAreaFilled(false);
        cashPay.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cashPayActionPerformed(evt);
            }
        });

        cardPay.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/Buttons/Card.png"))); // NOI18N
        cardPay.setBorderPainted(false);
        cardPay.setContentAreaFilled(false);
        cardPay.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cardPayActionPerformed(evt);
            }
        });

        cancelOrder.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/Buttons/Cancel.png"))); // NOI18N
        cancelOrder.setBorderPainted(false);
        cancelOrder.setContentAreaFilled(false);
        cancelOrder.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                cancelOrderActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel5Layout = new javax.swing.GroupLayout(jPanel5);
        jPanel5.setLayout(jPanel5Layout);
        jPanel5Layout.setHorizontalGroup(
            jPanel5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel5Layout.createSequentialGroup()
                .addComponent(cashPay, javax.swing.GroupLayout.PREFERRED_SIZE, 115, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(cardPay, javax.swing.GroupLayout.PREFERRED_SIZE, 115, javax.swing.GroupLayout.PREFERRED_SIZE))
            .addComponent(cancelOrder, javax.swing.GroupLayout.PREFERRED_SIZE, 0, Short.MAX_VALUE)
        );
        jPanel5Layout.setVerticalGroup(
            jPanel5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel5Layout.createSequentialGroup()
                .addGroup(jPanel5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(cashPay, javax.swing.GroupLayout.PREFERRED_SIZE, 75, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(cardPay, javax.swing.GroupLayout.PREFERRED_SIZE, 75, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(cancelOrder, javax.swing.GroupLayout.PREFERRED_SIZE, 89, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(41, Short.MAX_VALUE))
        );

        jLayeredPane1.setPreferredSize(new java.awt.Dimension(860, 406));

        jPanel7.setBackground(new java.awt.Color(255, 255, 255));

        jButton1.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuButtons/2.png"))); // NOI18N
        jButton1.setBorderPainted(false);
        jButton1.setContentAreaFilled(false);
        jButton1.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton1ActionPerformed(evt);
            }
        });

        jButton2.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuButtons/1.png"))); // NOI18N
        jButton2.setBorderPainted(false);
        jButton2.setContentAreaFilled(false);
        jButton2.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton2ActionPerformed(evt);
            }
        });

        jButton3.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuButtons/4.png"))); // NOI18N
        jButton3.setBorderPainted(false);
        jButton3.setContentAreaFilled(false);
        jButton3.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton3ActionPerformed(evt);
            }
        });

        jButton4.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuButtons/3.png"))); // NOI18N
        jButton4.setBorderPainted(false);
        jButton4.setContentAreaFilled(false);
        jButton4.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton4ActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel7Layout = new javax.swing.GroupLayout(jPanel7);
        jPanel7.setLayout(jPanel7Layout);
        jPanel7Layout.setHorizontalGroup(
            jPanel7Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel7Layout.createSequentialGroup()
                .addGap(0, 0, 0)
                .addGroup(jPanel7Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel7Layout.createSequentialGroup()
                        .addComponent(jButton2, javax.swing.GroupLayout.PREFERRED_SIZE, 420, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                        .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 420, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addGroup(jPanel7Layout.createSequentialGroup()
                        .addComponent(jButton4, javax.swing.GroupLayout.PREFERRED_SIZE, 420, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                        .addComponent(jButton3, javax.swing.GroupLayout.PREFERRED_SIZE, 420, javax.swing.GroupLayout.PREFERRED_SIZE))))
        );
        jPanel7Layout.setVerticalGroup(
            jPanel7Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel7Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel7Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jButton2)
                    .addComponent(jButton1, javax.swing.GroupLayout.Alignment.TRAILING))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addGroup(jPanel7Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addComponent(jButton3)
                    .addComponent(jButton4))
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        jLayeredPane1.setLayer(jPanel7, javax.swing.JLayeredPane.DEFAULT_LAYER);

        javax.swing.GroupLayout jLayeredPane1Layout = new javax.swing.GroupLayout(jLayeredPane1);
        jLayeredPane1.setLayout(jLayeredPane1Layout);
        jLayeredPane1Layout.setHorizontalGroup(
            jLayeredPane1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 846, Short.MAX_VALUE)
            .addGroup(jLayeredPane1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane1Layout.createSequentialGroup()
                    .addComponent(jPanel7, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addGap(0, 0, Short.MAX_VALUE)))
        );
        jLayeredPane1Layout.setVerticalGroup(
            jLayeredPane1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 559, Short.MAX_VALUE)
            .addGroup(jLayeredPane1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addComponent(jPanel7, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        jTabbedPane1.addTab("", new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuCategories/a.png")), jLayeredPane1); // NOI18N

        jPanel8.setBackground(new java.awt.Color(255, 255, 255));

        jLabel7.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel7.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/ItemsSolo/1.png"))); // NOI18N

        jPanel9.setBackground(new java.awt.Color(144, 56, 66));
        jPanel9.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));

        jSpinner1.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        jSpinner1.setModel(new javax.swing.SpinnerNumberModel(0, 0, null, 1));

        LatteSmall.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup1.add(LatteSmall);
        LatteSmall.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        LatteSmall.setForeground(new java.awt.Color(255, 255, 255));
        LatteSmall.setText("Small P140");
        LatteSmall.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                LatteSmallActionPerformed(evt);
            }
        });

        LatteMedium.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup1.add(LatteMedium);
        LatteMedium.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        LatteMedium.setForeground(new java.awt.Color(255, 255, 255));
        LatteMedium.setText("Medium P155");

        LatteLarge.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup1.add(LatteLarge);
        LatteLarge.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        LatteLarge.setForeground(new java.awt.Color(255, 255, 255));
        LatteLarge.setText("Large P170");

        jButton5.setBackground(new java.awt.Color(255, 255, 255));
        jButton5.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton5.setText("Add to Bill");
        jButton5.setBorderPainted(false);
        jButton5.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton5ActionPerformed(evt);
            }
        });

        jLabel8.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        jLabel8.setForeground(new java.awt.Color(255, 255, 255));
        jLabel8.setText("Quantity");

        javax.swing.GroupLayout jPanel9Layout = new javax.swing.GroupLayout(jPanel9);
        jPanel9.setLayout(jPanel9Layout);
        jPanel9Layout.setHorizontalGroup(
            jPanel9Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel9Layout.createSequentialGroup()
                .addContainerGap(63, Short.MAX_VALUE)
                .addComponent(jLabel8)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jSpinner1, javax.swing.GroupLayout.PREFERRED_SIZE, 40, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(32, 32, 32)
                .addComponent(LatteSmall)
                .addGap(18, 18, 18)
                .addComponent(LatteMedium)
                .addGap(18, 18, 18)
                .addComponent(LatteLarge)
                .addGap(47, 47, 47))
            .addGroup(jPanel9Layout.createSequentialGroup()
                .addGap(193, 193, 193)
                .addComponent(jButton5, javax.swing.GroupLayout.PREFERRED_SIZE, 202, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel9Layout.setVerticalGroup(
            jPanel9Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel9Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel9Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel9Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(jSpinner1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addComponent(jLabel8))
                    .addGroup(jPanel9Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(LatteSmall)
                        .addComponent(LatteMedium)
                        .addComponent(LatteLarge)))
                .addGap(10, 10, 10)
                .addComponent(jButton5, javax.swing.GroupLayout.PREFERRED_SIZE, 55, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout jPanel8Layout = new javax.swing.GroupLayout(jPanel8);
        jPanel8.setLayout(jPanel8Layout);
        jPanel8Layout.setHorizontalGroup(
            jPanel8Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel8Layout.createSequentialGroup()
                .addGap(125, 125, 125)
                .addComponent(jPanel9, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
            .addGroup(jPanel8Layout.createSequentialGroup()
                .addComponent(jLabel7, javax.swing.GroupLayout.PREFERRED_SIZE, 840, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(0, 0, Short.MAX_VALUE))
        );
        jPanel8Layout.setVerticalGroup(
            jPanel8Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel8Layout.createSequentialGroup()
                .addComponent(jLabel7, javax.swing.GroupLayout.PREFERRED_SIZE, 406, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(jPanel9, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap())
        );

        jLayeredPane2.setLayer(jPanel8, javax.swing.JLayeredPane.DEFAULT_LAYER);

        javax.swing.GroupLayout jLayeredPane2Layout = new javax.swing.GroupLayout(jLayeredPane2);
        jLayeredPane2.setLayout(jLayeredPane2Layout);
        jLayeredPane2Layout.setHorizontalGroup(
            jLayeredPane2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 845, Short.MAX_VALUE)
            .addGroup(jLayeredPane2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane2Layout.createSequentialGroup()
                    .addComponent(jPanel8, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addGap(0, 5, Short.MAX_VALUE)))
        );
        jLayeredPane2Layout.setVerticalGroup(
            jLayeredPane2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 558, Short.MAX_VALUE)
            .addGroup(jLayeredPane2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane2Layout.createSequentialGroup()
                    .addContainerGap()
                    .addComponent(jPanel8, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)))
        );

        jTabbedPane1.addTab("", new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuCategories/c.png")), jLayeredPane2); // NOI18N

        jPanel10.setBackground(new java.awt.Color(255, 255, 255));

        jLabel9.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel9.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/ItemsSolo/2.png"))); // NOI18N

        jPanel12.setBackground(new java.awt.Color(144, 56, 66));
        jPanel12.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));

        jSpinner3.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        jSpinner3.setModel(new javax.swing.SpinnerNumberModel(0, 0, null, 1));

        CcSmall.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup2.add(CcSmall);
        CcSmall.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        CcSmall.setForeground(new java.awt.Color(255, 255, 255));
        CcSmall.setText("Small P140");
        CcSmall.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                CcSmallActionPerformed(evt);
            }
        });

        CcMedium.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup2.add(CcMedium);
        CcMedium.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        CcMedium.setForeground(new java.awt.Color(255, 255, 255));
        CcMedium.setText("Medium P155");

        CcLarge.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup2.add(CcLarge);
        CcLarge.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        CcLarge.setForeground(new java.awt.Color(255, 255, 255));
        CcLarge.setText("Large P170");

        jButton7.setBackground(new java.awt.Color(255, 255, 255));
        jButton7.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton7.setText("Add to Bill");
        jButton7.setBorderPainted(false);
        jButton7.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton7ActionPerformed(evt);
            }
        });

        jLabel11.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        jLabel11.setForeground(new java.awt.Color(255, 255, 255));
        jLabel11.setText("Quantity");

        javax.swing.GroupLayout jPanel12Layout = new javax.swing.GroupLayout(jPanel12);
        jPanel12.setLayout(jPanel12Layout);
        jPanel12Layout.setHorizontalGroup(
            jPanel12Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel12Layout.createSequentialGroup()
                .addContainerGap(63, Short.MAX_VALUE)
                .addComponent(jLabel11)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jSpinner3, javax.swing.GroupLayout.PREFERRED_SIZE, 40, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(32, 32, 32)
                .addComponent(CcSmall)
                .addGap(18, 18, 18)
                .addComponent(CcMedium)
                .addGap(18, 18, 18)
                .addComponent(CcLarge)
                .addGap(47, 47, 47))
            .addGroup(jPanel12Layout.createSequentialGroup()
                .addGap(193, 193, 193)
                .addComponent(jButton7, javax.swing.GroupLayout.PREFERRED_SIZE, 202, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel12Layout.setVerticalGroup(
            jPanel12Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel12Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel12Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel12Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(jSpinner3, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addComponent(jLabel11))
                    .addGroup(jPanel12Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(CcSmall)
                        .addComponent(CcMedium)
                        .addComponent(CcLarge)))
                .addGap(10, 10, 10)
                .addComponent(jButton7, javax.swing.GroupLayout.PREFERRED_SIZE, 55, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout jPanel10Layout = new javax.swing.GroupLayout(jPanel10);
        jPanel10.setLayout(jPanel10Layout);
        jPanel10Layout.setHorizontalGroup(
            jPanel10Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel10Layout.createSequentialGroup()
                .addGap(125, 125, 125)
                .addComponent(jPanel12, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
            .addGroup(jPanel10Layout.createSequentialGroup()
                .addComponent(jLabel9, javax.swing.GroupLayout.PREFERRED_SIZE, 840, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(0, 0, Short.MAX_VALUE))
        );
        jPanel10Layout.setVerticalGroup(
            jPanel10Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel10Layout.createSequentialGroup()
                .addComponent(jLabel9, javax.swing.GroupLayout.PREFERRED_SIZE, 406, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jPanel12, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        jLayeredPane4.setLayer(jPanel10, javax.swing.JLayeredPane.DEFAULT_LAYER);

        javax.swing.GroupLayout jLayeredPane4Layout = new javax.swing.GroupLayout(jLayeredPane4);
        jLayeredPane4.setLayout(jLayeredPane4Layout);
        jLayeredPane4Layout.setHorizontalGroup(
            jLayeredPane4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 845, Short.MAX_VALUE)
            .addGroup(jLayeredPane4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane4Layout.createSequentialGroup()
                    .addComponent(jPanel10, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addGap(0, 5, Short.MAX_VALUE)))
        );
        jLayeredPane4Layout.setVerticalGroup(
            jLayeredPane4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 558, Short.MAX_VALUE)
            .addGroup(jLayeredPane4Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane4Layout.createSequentialGroup()
                    .addContainerGap()
                    .addComponent(jPanel10, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)))
        );

        jTabbedPane1.addTab("", new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuCategories/b.png")), jLayeredPane4); // NOI18N

        jPanel13.setBackground(new java.awt.Color(255, 255, 255));

        jLabel12.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel12.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/ItemsSolo/3.png"))); // NOI18N

        jPanel14.setBackground(new java.awt.Color(144, 56, 66));
        jPanel14.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));

        jSpinner4.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        jSpinner4.setModel(new javax.swing.SpinnerNumberModel(0, 0, null, 1));

        BbSmall.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup3.add(BbSmall);
        BbSmall.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        BbSmall.setForeground(new java.awt.Color(255, 255, 255));
        BbSmall.setText("Small P50");
        BbSmall.setActionCommand("");
        BbSmall.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                BbSmallActionPerformed(evt);
            }
        });

        BbMedium.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup3.add(BbMedium);
        BbMedium.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        BbMedium.setForeground(new java.awt.Color(255, 255, 255));
        BbMedium.setText("Medium P85");
        BbMedium.setActionCommand("");

        BbLarge.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup3.add(BbLarge);
        BbLarge.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        BbLarge.setForeground(new java.awt.Color(255, 255, 255));
        BbLarge.setText("Large P150");
        BbLarge.setActionCommand("");

        jButton8.setBackground(new java.awt.Color(255, 255, 255));
        jButton8.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton8.setText("Add to Bill");
        jButton8.setBorderPainted(false);
        jButton8.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton8ActionPerformed(evt);
            }
        });

        jLabel13.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        jLabel13.setForeground(new java.awt.Color(255, 255, 255));
        jLabel13.setText("Quantity");

        javax.swing.GroupLayout jPanel14Layout = new javax.swing.GroupLayout(jPanel14);
        jPanel14.setLayout(jPanel14Layout);
        jPanel14Layout.setHorizontalGroup(
            jPanel14Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel14Layout.createSequentialGroup()
                .addContainerGap(71, Short.MAX_VALUE)
                .addComponent(jLabel13)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jSpinner4, javax.swing.GroupLayout.PREFERRED_SIZE, 40, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(32, 32, 32)
                .addComponent(BbSmall)
                .addGap(18, 18, 18)
                .addComponent(BbMedium)
                .addGap(18, 18, 18)
                .addComponent(BbLarge)
                .addGap(47, 47, 47))
            .addGroup(jPanel14Layout.createSequentialGroup()
                .addGap(193, 193, 193)
                .addComponent(jButton8, javax.swing.GroupLayout.PREFERRED_SIZE, 202, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel14Layout.setVerticalGroup(
            jPanel14Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel14Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel14Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel14Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(jSpinner4, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addComponent(jLabel13))
                    .addGroup(jPanel14Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(BbSmall)
                        .addComponent(BbMedium)
                        .addComponent(BbLarge)))
                .addGap(10, 10, 10)
                .addComponent(jButton8, javax.swing.GroupLayout.PREFERRED_SIZE, 55, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        BbSmall.getAccessibleContext().setAccessibleName("");

        javax.swing.GroupLayout jPanel13Layout = new javax.swing.GroupLayout(jPanel13);
        jPanel13.setLayout(jPanel13Layout);
        jPanel13Layout.setHorizontalGroup(
            jPanel13Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel13Layout.createSequentialGroup()
                .addGroup(jPanel13Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel13Layout.createSequentialGroup()
                        .addGap(125, 125, 125)
                        .addComponent(jPanel14, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addComponent(jLabel12, javax.swing.GroupLayout.PREFERRED_SIZE, 840, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel13Layout.setVerticalGroup(
            jPanel13Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel13Layout.createSequentialGroup()
                .addComponent(jLabel12, javax.swing.GroupLayout.PREFERRED_SIZE, 406, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(jPanel14, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap())
        );

        jLayeredPane5.setLayer(jPanel13, javax.swing.JLayeredPane.DEFAULT_LAYER);

        javax.swing.GroupLayout jLayeredPane5Layout = new javax.swing.GroupLayout(jLayeredPane5);
        jLayeredPane5.setLayout(jLayeredPane5Layout);
        jLayeredPane5Layout.setHorizontalGroup(
            jLayeredPane5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 850, Short.MAX_VALUE)
            .addGroup(jLayeredPane5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addComponent(jPanel13, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jLayeredPane5Layout.setVerticalGroup(
            jLayeredPane5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 558, Short.MAX_VALUE)
            .addGroup(jLayeredPane5Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane5Layout.createSequentialGroup()
                    .addContainerGap()
                    .addComponent(jPanel13, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)))
        );

        jTabbedPane1.addTab("", new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuCategories/d.png")), jLayeredPane5); // NOI18N

        jLayeredPane6.setCursor(new java.awt.Cursor(java.awt.Cursor.DEFAULT_CURSOR));
        jLayeredPane6.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        jLayeredPane6.setMaximumSize(new java.awt.Dimension(600, 600));

        jPanel15.setBackground(new java.awt.Color(255, 255, 255));

        jLabel14.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);
        jLabel14.setIcon(new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/ItemsSolo/4.png"))); // NOI18N

        jPanel16.setBackground(new java.awt.Color(144, 56, 66));
        jPanel16.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(144, 56, 66), 1, true));

        jSpinner5.setFont(new java.awt.Font("Montserrat", 0, 11)); // NOI18N
        jSpinner5.setModel(new javax.swing.SpinnerNumberModel(0, 0, null, 1));

        ScSmall.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup4.add(ScSmall);
        ScSmall.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        ScSmall.setForeground(new java.awt.Color(255, 255, 255));
        ScSmall.setText("Small P100");
        ScSmall.setActionCommand("");
        ScSmall.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                ScSmallActionPerformed(evt);
            }
        });

        ScMedium.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup4.add(ScMedium);
        ScMedium.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        ScMedium.setForeground(new java.awt.Color(255, 255, 255));
        ScMedium.setText("Medium P185");
        ScMedium.setActionCommand("");

        ScLarge.setBackground(new java.awt.Color(144, 56, 66));
        buttonGroup4.add(ScLarge);
        ScLarge.setFont(new java.awt.Font("Montserrat", 0, 12)); // NOI18N
        ScLarge.setForeground(new java.awt.Color(255, 255, 255));
        ScLarge.setText("Large P250");
        ScLarge.setActionCommand("");

        jButton9.setBackground(new java.awt.Color(255, 255, 255));
        jButton9.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton9.setText("Add to Bill");
        jButton9.setBorderPainted(false);
        jButton9.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton9ActionPerformed(evt);
            }
        });

        jLabel15.setFont(new java.awt.Font("Montserrat", 0, 18)); // NOI18N
        jLabel15.setForeground(new java.awt.Color(255, 255, 255));
        jLabel15.setText("Quantity");

        javax.swing.GroupLayout jPanel16Layout = new javax.swing.GroupLayout(jPanel16);
        jPanel16.setLayout(jPanel16Layout);
        jPanel16Layout.setHorizontalGroup(
            jPanel16Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel16Layout.createSequentialGroup()
                .addContainerGap(57, Short.MAX_VALUE)
                .addComponent(jLabel15)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jSpinner5, javax.swing.GroupLayout.PREFERRED_SIZE, 40, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(32, 32, 32)
                .addComponent(ScSmall)
                .addGap(18, 18, 18)
                .addComponent(ScMedium)
                .addGap(18, 18, 18)
                .addComponent(ScLarge)
                .addGap(47, 47, 47))
            .addGroup(jPanel16Layout.createSequentialGroup()
                .addGap(193, 193, 193)
                .addComponent(jButton9, javax.swing.GroupLayout.PREFERRED_SIZE, 202, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );
        jPanel16Layout.setVerticalGroup(
            jPanel16Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel16Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel16Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel16Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(jSpinner5, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addComponent(jLabel15))
                    .addGroup(jPanel16Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.BASELINE)
                        .addComponent(ScSmall)
                        .addComponent(ScMedium)
                        .addComponent(ScLarge)))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, 10, Short.MAX_VALUE)
                .addComponent(jButton9, javax.swing.GroupLayout.PREFERRED_SIZE, 55, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap())
        );

        javax.swing.GroupLayout jPanel15Layout = new javax.swing.GroupLayout(jPanel15);
        jPanel15.setLayout(jPanel15Layout);
        jPanel15Layout.setHorizontalGroup(
            jPanel15Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jLabel14, javax.swing.GroupLayout.Alignment.TRAILING, javax.swing.GroupLayout.PREFERRED_SIZE, 840, javax.swing.GroupLayout.PREFERRED_SIZE)
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel15Layout.createSequentialGroup()
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(jPanel16, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(125, 125, 125))
        );
        jPanel15Layout.setVerticalGroup(
            jPanel15Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel15Layout.createSequentialGroup()
                .addComponent(jLabel14, javax.swing.GroupLayout.PREFERRED_SIZE, 406, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jPanel16, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
        );

        jLayeredPane6.setLayer(jPanel15, javax.swing.JLayeredPane.DEFAULT_LAYER);

        javax.swing.GroupLayout jLayeredPane6Layout = new javax.swing.GroupLayout(jLayeredPane6);
        jLayeredPane6.setLayout(jLayeredPane6Layout);
        jLayeredPane6Layout.setHorizontalGroup(
            jLayeredPane6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 845, Short.MAX_VALUE)
            .addGroup(jLayeredPane6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane6Layout.createSequentialGroup()
                    .addComponent(jPanel15, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addGap(0, 0, Short.MAX_VALUE)))
        );
        jLayeredPane6Layout.setVerticalGroup(
            jLayeredPane6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGap(0, 558, Short.MAX_VALUE)
            .addGroup(jLayeredPane6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                .addGroup(jLayeredPane6Layout.createSequentialGroup()
                    .addContainerGap()
                    .addComponent(jPanel15, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)))
        );

        jTabbedPane1.addTab("", new javax.swing.ImageIcon(getClass().getResource("/GUI/Assets/MenuCategories/e.png")), jLayeredPane6); // NOI18N

        javax.swing.GroupLayout jPanel6Layout = new javax.swing.GroupLayout(jPanel6);
        jPanel6.setLayout(jPanel6Layout);
        jPanel6Layout.setHorizontalGroup(
            jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel6Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel6Layout.createSequentialGroup()
                        .addComponent(Logo)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                        .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE))
                    .addComponent(jTabbedPane1, javax.swing.GroupLayout.PREFERRED_SIZE, 850, javax.swing.GroupLayout.PREFERRED_SIZE))
                .addGap(10, 10, 10)
                .addGroup(jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.TRAILING)
                    .addComponent(jPanel2, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                    .addComponent(jPanel4, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                    .addComponent(jPanel5, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
                .addContainerGap())
        );
        jPanel6Layout.setVerticalGroup(
            jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel6Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel6Layout.createSequentialGroup()
                        .addGap(91, 91, 91)
                        .addComponent(jPanel4, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                        .addComponent(jPanel5, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
                    .addGroup(jPanel6Layout.createSequentialGroup()
                        .addGroup(jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.TRAILING)
                            .addComponent(Logo, javax.swing.GroupLayout.PREFERRED_SIZE, 148, javax.swing.GroupLayout.PREFERRED_SIZE)
                            .addGroup(jPanel6Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                                .addComponent(jPanel2, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                                .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)))
                        .addGap(3, 3, 3)
                        .addComponent(jTabbedPane1, javax.swing.GroupLayout.PREFERRED_SIZE, 0, Short.MAX_VALUE)
                        .addContainerGap())))
        );

        setJMenuBar(jMenuBar1);

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel6, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel6, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
        );

        pack();
    }// </editor-fold>                        

    private void ScSmallActionPerformed(java.awt.event.ActionEvent evt) {                                        
        // TODO add your handling code here:
    }                                       

    private void BbSmallActionPerformed(java.awt.event.ActionEvent evt) {                                        
        // TODO add your handling code here:
    }                                       

    private void CcSmallActionPerformed(java.awt.event.ActionEvent evt) {                                        
        // TODO add your handling code here:
    }                                       

    private void LatteSmallActionPerformed(java.awt.event.ActionEvent evt) {                                           
        // TODO add your handling code here:
    }                                          

    private void jButton4ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        jTabbedPane1.setSelectedIndex(3);
    }                                        

    private void jButton3ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        jTabbedPane1.setSelectedIndex(4);
    }                                        

    private void jButton2ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        jTabbedPane1.setSelectedIndex(1);
    }                                        

    private void jButton1ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        jTabbedPane1.setSelectedIndex(2);
    }                                        

    private void jButton15ActionPerformed(java.awt.event.ActionEvent evt) {                                          
        new MainMenu().setVisible(true);
        dispose();
    }                                         

    private void jButton5ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        String LatteItem = "";
        int LatteSmallPriceEach = 140;
        int LatteMediumPriceEach = 155;
        int LatteLargePriceEach = 170;
        String LattePrice = "";

        int rowCount = jTable1.getRowCount();
        
        
        String LatteQuan = jSpinner1.getValue().toString();

        int quantity = (int) jSpinner1.getValue();

        int LatteSmallPriceTotal = LatteSmallPriceEach*quantity;
        int LatteMediumPriceTotal = LatteMediumPriceEach*quantity;
        int LatteLargePriceTotal = LatteLargePriceEach*quantity;

        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();
        
        
        if(LatteSmall.isSelected()) // if tall is selected
        {
            LatteItem = "Latte Small";
            LattePrice = String.valueOf(LatteSmallPriceTotal);
            totalAmountDue = totalAmountDue + LatteSmallPriceTotal;
            String data[]={LatteItem, LatteQuan, LattePrice};                       
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Latte Small")){
                    updateLSLock=1;
                }
            }
            
            if(updateLSLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Latte Small";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(LattePrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }
            
            else{
                tblModel.addRow(data);
            }
            
            updateLSLock=0;
        }

        else if(LatteMedium.isSelected()) // if grande is selected
        {
            LatteItem = "Latte Medium";
            LattePrice = String.valueOf(LatteMediumPriceTotal);
            totalAmountDue = totalAmountDue + LatteMediumPriceTotal;
            String data[]={LatteItem, LatteQuan, LattePrice}; 
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Latte Medium")){
                    updateLMLock=1;
                }
            }
            
            if(updateLMLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Latte Medium";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(LattePrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }
            
            else{
                tblModel.addRow(data);
                
            }
            updateLMLock=0;
        }

        else if(LatteLarge.isSelected()) // if venti is selected
        {
            LatteItem = "Latte Large";
            LattePrice = String.valueOf(LatteLargePriceTotal);
            totalAmountDue = totalAmountDue + LatteLargePriceTotal;
            String data[]={LatteItem, LatteQuan, LattePrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Latte Large")){
                    updateLLLock=1;
                }
            }
            
            if(updateLLLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Latte Large";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(LattePrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }
            
            else{
                tblModel.addRow(data);               
            }
            updateLLLock=0;
        }         
        totalOrderPrice.setText(String.valueOf(totalAmountDue));    
    }                                        

    private void jButton7ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        String CcItem = "";
        int CcSmallPriceEach = 140;
        int CcMediumPriceEach = 155;
        int CcLargePriceEach = 170;
        String CcPrice = "";
        
        int rowCount = jTable1.getRowCount();
        
        String CcQuan = jSpinner3.getValue().toString();
        
        int quantity = (int) jSpinner3.getValue();
        
        int CcSmallPriceTotal = CcSmallPriceEach*quantity;
        int CcMediumPriceTotal = CcMediumPriceEach*quantity;
        int CcLargePriceTotal = CcLargePriceEach*quantity;
        
        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();
        
        if(CcSmall.isSelected()) // if tall is selected
        {
            CcItem = "Chocolate Chip Small";
            CcPrice = String.valueOf(CcSmallPriceTotal);
            totalAmountDue = totalAmountDue + CcSmallPriceTotal;
            String data[]={CcItem, CcQuan, CcPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Small")){
                    updateCCSLock=1;
                }
            }
          
            if(updateCCSLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Chocolate Chip Small";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(CcPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }
            
            else{
                tblModel.addRow(data);                
            }
            updateCCSLock=0;
        }
        
        else if(CcMedium.isSelected()) // if grande is selected
        {
            CcItem = "Chocolate Chip Medium";
            CcPrice = String.valueOf(CcMediumPriceTotal);
            totalAmountDue = totalAmountDue + CcMediumPriceTotal;
            String data[]={CcItem, CcQuan, CcPrice};
          
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Medium")){
                    updateCCMLock=1;
                }
            }
            
            if(updateCCMLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Chocolate Chip Medium";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(CcPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateCCMLock=0;
        }       
        else if(CcLarge.isSelected()) // if venti is selected
        {
            CcItem = "Chocolate Chip Large";
            CcPrice = String.valueOf(CcLargePriceTotal);
            totalAmountDue = totalAmountDue + CcLargePriceTotal;
            String data[]={CcItem, CcQuan, CcPrice};
          
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Large")){
                    updateCCLLock=1;
                }
            }
            
            if(updateCCLLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Chocolate Chip Large";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(CcPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateCCLLock=0;
        }               
        totalOrderPrice.setText(String.valueOf(totalAmountDue));
    }                                        

    private void jButton8ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        String BbItem = "";
        int BbSmallPriceEach = 50;
        int BbMediumPriceEach = 85;
        int BbLargePriceEach = 150;
        String BbPrice = "";

        int rowCount = jTable1.getRowCount();
        
        String BbQuan = jSpinner4.getValue().toString();

        int quantity = (int) jSpinner4.getValue();

        int BbSmallPriceTotal = BbSmallPriceEach*quantity;
        int BbMediumPriceTotal = BbMediumPriceEach*quantity;
        int BbLargePriceTotal = BbLargePriceEach*quantity;
        
        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();

        if(BbSmall.isSelected()) // if tall is selected
        {
            BbItem = "Banana Bread Small";
            BbPrice = String.valueOf(BbSmallPriceTotal);
            totalAmountDue = totalAmountDue + BbSmallPriceTotal;
            String data[]={BbItem, BbQuan, BbPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Small")){
                    updateBBSLock=1;
                }
            }
            
            if(updateBBSLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Banana Bread Small";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(BbPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateBBSLock=0;
        }

        else if(BbMedium.isSelected()) // if grande is selected
        {
            BbItem = "Banana Bread Medium";
            BbPrice = String.valueOf(BbMediumPriceTotal);
            totalAmountDue = totalAmountDue + BbMediumPriceTotal;
            String data[]={BbItem, BbQuan, BbPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Medium")){
                    updateBBMLock=1;
                }
            }
            
            if(updateBBMLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Banana Bread Medium";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(BbPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateBBMLock=0;
        }

        else if(BbLarge.isSelected()) // if venti is selected
        {
            BbItem = "Banana Bread Large";
            BbPrice = String.valueOf(BbLargePriceTotal);
            totalAmountDue = totalAmountDue + BbLargePriceTotal;
            String data[]={BbItem, BbQuan, BbPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Large")){
                    updateBBLLock=1;
                }
            }
            
            if(updateBBLLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Banana Bread Large";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(BbPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateBBLLock=0;
        }  
        totalOrderPrice.setText(String.valueOf(totalAmountDue));
    }                                        

    private void jButton9ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        String ScItem = "";
        int ScSmallPriceEach = 100;
        int ScMediumPriceEach = 185;
        int ScLargePriceEach = 250;
        String ScPrice = "";

        int rowCount = jTable1.getRowCount();
        
        String ScQuan = jSpinner5.getValue().toString();

        int quantity = (int) jSpinner5.getValue();

        int ScSmallPriceTotal = ScSmallPriceEach*quantity;
        int ScMediumPriceTotal = ScMediumPriceEach*quantity;
        int ScLargePriceTotal = ScLargePriceEach*quantity;

        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();
        
        if(ScSmall.isSelected()) // if tall is selected
        {
            ScItem = "Strawberry Cheesecake Small";
            ScPrice = String.valueOf(ScSmallPriceTotal);
            totalAmountDue = totalAmountDue + ScSmallPriceTotal;
            String data[]={ScItem, ScQuan, ScPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Small")){
                    updateSCSLock=1;
                }
            }
            
            if(updateSCSLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Strawberry Cheesecake Small";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(ScPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateSCSLock=0;
        }

        else if(ScMedium.isSelected()) // if grande is selected
        {
            ScItem = "Strawberry Cheesecake Medium";
            ScPrice = String.valueOf(ScMediumPriceTotal);
            totalAmountDue = totalAmountDue + ScMediumPriceTotal;
            String data[]={ScItem, ScQuan, ScPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Medium")){
                    updateSCMLock=1;
                }
            }
            
            if(updateSCMLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Strawberry Cheesecake Medium";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(ScPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);

            }
            updateSCMLock=0;
        }

        else if(ScLarge.isSelected()) // if venti is selected
        {
            ScItem = "Strawberry Cheesecake Large";
            ScPrice = String.valueOf(ScLargePriceTotal);
            totalAmountDue = totalAmountDue + ScLargePriceTotal;
            String data[]={ScItem, ScQuan, ScPrice};
            
            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Large")){
                    updateSCLLock=1;
                }
            }
            
            if(updateSCLLock==1){
                for(int i=0; i<rowCount; i++){

                    String targetItem="Strawberry Cheesecake Large";
                    String tableVal = tblModel.getValueAt(i,0).toString();
                    String targetQuan;
                    String targetPrice;
                    int updateQuan;
                    int updatePrice;

                    if(targetItem.equals(tableVal)){

                        targetQuan = tblModel.getValueAt(i, 1).toString();
                        targetPrice = tblModel.getValueAt(i, 2).toString();
                        updateQuan = Integer.valueOf(targetQuan)+quantity;
                        updatePrice = Integer.valueOf(targetPrice)+Integer.valueOf(ScPrice);
                        tblModel.setValueAt(updateQuan, i, 1);
                        tblModel.setValueAt(updatePrice, i, 2);
                    }            
                }
            }            
            else{
                tblModel.addRow(data);
            }
            updateSCLLock=0;
        }  
        totalOrderPrice.setText(String.valueOf(totalAmountDue));
    }                                        

    private void cashPayActionPerformed(java.awt.event.ActionEvent evt) {                                        
        
        String orderListEntry="";
            
        int rowCount = jTable1.getRowCount();
            
        if(rowCount == 0){
            JOptionPane.showMessageDialog(this, "No Orders Made");
        }
        
        else{
        
            DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();

            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Latte Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Latte Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Latte Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCLarge ";
                }
            }

            new CashPayment(totalAmountDue, crewName, orderListEntry).setVisible(true);
            dispose();
        }
    }                                       

    private void cardPayActionPerformed(java.awt.event.ActionEvent evt) {                                        
        
        String orderListEntry="";
            
        int rowCount = jTable1.getRowCount();
        
        if(rowCount == 0){
            JOptionPane.showMessageDialog(this, "No Orders Made");
        }
        
        else{
            
            DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();

            for(int i=0; i<rowCount; i++){
                if(tblModel.getValueAt(i,0).toString().equals("Latte Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Latte Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Latte Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xLatteLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Chocolate Chip Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xCCLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Banana Bread Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xBBLarge ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Small")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCSmall ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Medium")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCMedium ";
                }

                if(tblModel.getValueAt(i,0).toString().equals("Strawberry Cheesecake Large")){
                    orderListEntry+=tblModel.getValueAt(i, 1).toString()+"xSCLarge ";
                }
            }

            new CardPayment(totalAmountDue, crewName, orderListEntry).setVisible(true);
            dispose();
        }
    }                                       

    private void cancelOrderActionPerformed(java.awt.event.ActionEvent evt) {                                            
        totalAmountDue = 0;
        totalOrderPrice.setText(String.valueOf(totalAmountDue));
        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();
        tblModel.setRowCount(0);
    }                                           

    private void logoutBtnActionPerformed(java.awt.event.ActionEvent evt) {                                          
        new LoginPage().setVisible(true);
        dispose();
    }                                         

    private void deleteSelectedOrderActionPerformed(java.awt.event.ActionEvent evt) {                                                    
        DefaultTableModel tblModel = (DefaultTableModel)jTable1.getModel();
        String selectedPrice = tblModel.getValueAt(jTable1.getSelectedRow(), 2).toString();
        
        totalAmountDue = totalAmountDue - Integer.valueOf(selectedPrice);
        
        totalOrderPrice.setText(String.valueOf(totalAmountDue));
        
        if(jTable1.getSelectedRowCount()==1){
            tblModel.removeRow(jTable1.getSelectedRow());
        }
        
        else{
            JOptionPane.showMessageDialog(this, "Select an order to delete");
        }
        
    }                                                   

    private void jTable1MouseClicked(java.awt.event.MouseEvent evt) {                                     
        // TODO add your handling code here:
    }                                    

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(MenuPageTabbed.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(MenuPageTabbed.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(MenuPageTabbed.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(MenuPageTabbed.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new MenuPageTabbed().setVisible(true);
            }
        });
    }   
   

    // Variables declaration - do not modify                     
    private javax.swing.JRadioButton BbLarge;
    private javax.swing.JRadioButton BbMedium;
    private javax.swing.JRadioButton BbSmall;
    private javax.swing.JRadioButton CcLarge;
    private javax.swing.JRadioButton CcMedium;
    private javax.swing.JRadioButton CcSmall;
    private javax.swing.JRadioButton LatteLarge;
    private javax.swing.JRadioButton LatteMedium;
    private javax.swing.JRadioButton LatteSmall;
    private javax.swing.JLabel Logo;
    private javax.swing.JRadioButton ScLarge;
    private javax.swing.JRadioButton ScMedium;
    private javax.swing.JRadioButton ScSmall;
    private javax.swing.ButtonGroup buttonGroup1;
    private javax.swing.ButtonGroup buttonGroup2;
    private javax.swing.ButtonGroup buttonGroup3;
    private javax.swing.ButtonGroup buttonGroup4;
    private javax.swing.JButton cancelOrder;
    private javax.swing.JButton cardPay;
    private javax.swing.JButton cashPay;
    private javax.swing.JButton deleteSelectedOrder;
    private javax.swing.JLabel greetingLabel;
    private javax.swing.JButton jButton1;
    private javax.swing.JButton jButton15;
    private javax.swing.JButton jButton2;
    private javax.swing.JButton jButton3;
    private javax.swing.JButton jButton4;
    private javax.swing.JButton jButton5;
    private javax.swing.JButton jButton7;
    private javax.swing.JButton jButton8;
    private javax.swing.JButton jButton9;
    private javax.swing.JLabel jLabel1;
    private javax.swing.JLabel jLabel11;
    private javax.swing.JLabel jLabel12;
    private javax.swing.JLabel jLabel13;
    private javax.swing.JLabel jLabel14;
    private javax.swing.JLabel jLabel15;
    private javax.swing.JLabel jLabel2;
    private javax.swing.JLabel jLabel3;
    private javax.swing.JLabel jLabel4;
    private javax.swing.JLabel jLabel7;
    private javax.swing.JLabel jLabel8;
    private javax.swing.JLabel jLabel9;
    private javax.swing.JLayeredPane jLayeredPane1;
    private javax.swing.JLayeredPane jLayeredPane2;
    private javax.swing.JLayeredPane jLayeredPane3;
    private javax.swing.JLayeredPane jLayeredPane4;
    private javax.swing.JLayeredPane jLayeredPane5;
    private javax.swing.JLayeredPane jLayeredPane6;
    private javax.swing.JMenuBar jMenuBar1;
    private javax.swing.JPanel jPanel1;
    private javax.swing.JPanel jPanel10;
    private javax.swing.JPanel jPanel12;
    private javax.swing.JPanel jPanel13;
    private javax.swing.JPanel jPanel14;
    private javax.swing.JPanel jPanel15;
    private javax.swing.JPanel jPanel16;
    private javax.swing.JPanel jPanel2;
    private javax.swing.JPanel jPanel3;
    private javax.swing.JPanel jPanel4;
    private javax.swing.JPanel jPanel5;
    private javax.swing.JPanel jPanel6;
    private javax.swing.JPanel jPanel7;
    private javax.swing.JPanel jPanel8;
    private javax.swing.JPanel jPanel9;
    private javax.swing.JScrollPane jScrollPane1;
    private javax.swing.JSeparator jSeparator3;
    private javax.swing.JSpinner jSpinner1;
    private javax.swing.JSpinner jSpinner3;
    private javax.swing.JSpinner jSpinner4;
    private javax.swing.JSpinner jSpinner5;
    private javax.swing.JTabbedPane jTabbedPane1;
    private javax.swing.JTable jTable1;
    private javax.swing.JButton logoutBtn;
    private javax.swing.JLabel totalOrderPrice;
    // End of variables declaration                   

    
}

# %% [markdown]
# **Cash Payment**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

import java.sql.*;
import javax.swing.JOptionPane;

/**
 *
 * 
 */
public class CashPayment extends javax.swing.JFrame {

    int totalAmountDue;
    int paymentCompleteLock=0;
    String crewName;
    String orderListEntry;
    /**
     * Creates new form CashPayment
     */
    public CashPayment() {
        initComponents();
    }
    
    public CashPayment(int tAD, String crewInCharge, String OLE){
        initComponents();
        
        totalAmountDue = tAD;
        crewName = crewInCharge;
        orderListEntry = OLE;

        totalDisplay.setText("P"+String.valueOf(totalAmountDue));
    }
    
    
    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jPanel1 = new javax.swing.JPanel();
        jLabel1 = new javax.swing.JLabel();
        jLabel2 = new javax.swing.JLabel();
        jButton1 = new javax.swing.JButton();
        paymentInput = new javax.swing.JTextField();
        jPanel2 = new javax.swing.JPanel();
        changeTendered = new javax.swing.JLabel();
        jLabel3 = new javax.swing.JLabel();
        totalDisplay = new javax.swing.JLabel();
        backBtn = new javax.swing.JButton();
        paymentError = new javax.swing.JLabel();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);

        jPanel1.setBackground(new java.awt.Color(144, 56, 66));

        jLabel1.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        jLabel1.setForeground(new java.awt.Color(255, 255, 255));
        jLabel1.setText("Change");

        jLabel2.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        jLabel2.setForeground(new java.awt.Color(255, 255, 255));
        jLabel2.setText("Amount Tendered");

        jButton1.setBackground(new java.awt.Color(255, 255, 255));
        jButton1.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton1.setText("Payment Complete");
        jButton1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(255, 255, 255), 1, true));
        jButton1.setBorderPainted(false);
        jButton1.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton1ActionPerformed(evt);
            }
        });

        paymentInput.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        paymentInput.setHorizontalAlignment(javax.swing.JTextField.CENTER);

        changeTendered.setFont(new java.awt.Font("Arial", 0, 24)); // NOI18N
        changeTendered.setHorizontalAlignment(javax.swing.SwingConstants.CENTER);

        javax.swing.GroupLayout jPanel2Layout = new javax.swing.GroupLayout(jPanel2);
        jPanel2.setLayout(jPanel2Layout);
        jPanel2Layout.setHorizontalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel2Layout.createSequentialGroup()
                .addContainerGap()
                .addComponent(changeTendered, javax.swing.GroupLayout.DEFAULT_SIZE, 345, Short.MAX_VALUE)
                .addContainerGap())
        );
        jPanel2Layout.setVerticalGroup(
            jPanel2Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(changeTendered, javax.swing.GroupLayout.PREFERRED_SIZE, 51, javax.swing.GroupLayout.PREFERRED_SIZE)
        );

        jLabel3.setFont(new java.awt.Font("Arial", 1, 24)); // NOI18N
        jLabel3.setForeground(new java.awt.Color(255, 255, 255));
        jLabel3.setText("Total:");

        totalDisplay.setFont(new java.awt.Font("Arial", 1, 24)); // NOI18N
        totalDisplay.setForeground(new java.awt.Color(255, 255, 255));

        backBtn.setText("Back");
        backBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                backBtnActionPerformed(evt);
            }
        });

        paymentError.setForeground(new java.awt.Color(255, 255, 255));

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addContainerGap()
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(0, 0, Short.MAX_VALUE)
                        .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                                .addComponent(jLabel2)
                                .addGap(82, 82, 82))
                            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.TRAILING)
                                    .addGroup(jPanel1Layout.createSequentialGroup()
                                        .addComponent(jLabel1)
                                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                                        .addComponent(paymentError, javax.swing.GroupLayout.PREFERRED_SIZE, 122, javax.swing.GroupLayout.PREFERRED_SIZE)
                                        .addGap(6, 6, 6))
                                    .addComponent(jPanel2, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                                    .addComponent(paymentInput, javax.swing.GroupLayout.PREFERRED_SIZE, 365, javax.swing.GroupLayout.PREFERRED_SIZE))
                                .addGap(36, 36, 36))))
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addComponent(jLabel3)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                        .addComponent(totalDisplay, javax.swing.GroupLayout.PREFERRED_SIZE, 333, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addGap(36, 36, 36))))
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(197, 197, 197)
                .addComponent(backBtn)
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
            .addGroup(javax.swing.GroupLayout.Alignment.TRAILING, jPanel1Layout.createSequentialGroup()
                .addContainerGap(javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 280, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(79, 79, 79))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(36, 36, 36)
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING, false)
                    .addComponent(jLabel3, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
                    .addComponent(totalDisplay, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
                .addGap(18, 18, 18)
                .addComponent(jLabel2)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(paymentInput, javax.swing.GroupLayout.PREFERRED_SIZE, 73, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addComponent(paymentError, javax.swing.GroupLayout.PREFERRED_SIZE, 15, javax.swing.GroupLayout.PREFERRED_SIZE)
                        .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE))
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(0, 18, Short.MAX_VALUE)
                        .addComponent(jLabel1)))
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jPanel2, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(41, 41, 41)
                .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 50, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.UNRELATED)
                .addComponent(backBtn)
                .addGap(15, 15, 15))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
        );

        pack();
    }// </editor-fold>                        

    private void jButton1ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        
        
        String paymentString = "";
        paymentString = paymentInput.getText();        
        int paymentInt = Integer.valueOf(paymentString);        
        int change = paymentInt - totalAmountDue;
        
        if(paymentCompleteLock==0){
            if(paymentInt>=totalAmountDue){

                changeTendered.setText(String.valueOf(change));

                try{
                    Class.forName("com.mysql.jdbc.Driver");
                    Connection cn = DriverManager.getConnection("jdbc:mysql://remotemysql.com:3306/SlroZZ8W9B","SlroZZ8W9B","xEvUdzqfTW");

                    String query="insert into ordertable(orderList, priceTotal, paymentMethod, crewInCharge) values(?,?,?,?)";
                    PreparedStatement MyPst=cn.prepareStatement(query);
                    MyPst.setString(1, orderListEntry);
                    MyPst.setString(2, String.valueOf(totalAmountDue));
                    MyPst.setString(3, "Cash");
                    MyPst.setString(4, crewName);

                    MyPst.execute();
                    MyPst.close();            
                    cn.close();

                }catch(Exception e){            
                    System.out.println(e.getMessage());            
                }
                paymentCompleteLock=1;
                paymentError.setText("");
                JOptionPane.showMessageDialog(this, "Transaction Complete\nClick 'Back' to Continue");
            }
            else{
                paymentError.setText("Insufficient Payment");
            }
        }
        else{
            JOptionPane.showMessageDialog(this, "Payment is already finished\nClick 'Back' to Continue");
        }
    }                                        

    private void backBtnActionPerformed(java.awt.event.ActionEvent evt) {                                        
        
        if(paymentCompleteLock==0){
            new MenuPageTabbed(crewName).setVisible(true);
            dispose();
        }
        
        else if(paymentCompleteLock==1){
            new MainMenu(crewName).setVisible(true);
            dispose();
        }
    }                                       

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(CashPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(CashPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(CashPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(CashPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new CashPayment().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JButton backBtn;
    private javax.swing.JLabel changeTendered;
    private javax.swing.JButton jButton1;
    private javax.swing.JLabel jLabel1;
    private javax.swing.JLabel jLabel2;
    private javax.swing.JLabel jLabel3;
    private javax.swing.JPanel jPanel1;
    private javax.swing.JPanel jPanel2;
    private javax.swing.JLabel paymentError;
    private javax.swing.JTextField paymentInput;
    private javax.swing.JLabel totalDisplay;
    // End of variables declaration                   
}

# %% [markdown]
# **Card Payment**

# %%
/*
 * Click nbfs://nbhost/SystemFileSystem/Templates/Licenses/license-default.txt to change this license
 * Click nbfs://nbhost/SystemFileSystem/Templates/GUIForms/JFrame.java to edit this template
 */
package GUI;

import java.sql.*;

/**
 *
 * 
 */
public class CardPayment extends javax.swing.JFrame {
  
    int totalAmountDue;
    String crewName;
    String orderListEntry;
    /**
     * Creates new form CashPayment 
     */
    public CardPayment() {
        initComponents();
    }

    public CardPayment(int tAD, String crewInCharge, String OLE) {
        initComponents();
        
        totalAmountDue = tAD;
        crewName = crewInCharge;
        orderListEntry = OLE;
    }
    
    /**
     * This method is called from within the constructor to initialize the form.
     * WARNING: Do NOT modify this code. The content of this method is always
     * regenerated by the Form Editor.
     */
    @SuppressWarnings("unchecked")
    // <editor-fold defaultstate="collapsed" desc="Generated Code">                          
    private void initComponents() {

        jPanel1 = new javax.swing.JPanel();
        jLabel2 = new javax.swing.JLabel();
        jButton1 = new javax.swing.JButton();
        jLabel3 = new javax.swing.JLabel();
        jLabel4 = new javax.swing.JLabel();
        backBtn = new javax.swing.JButton();

        setDefaultCloseOperation(javax.swing.WindowConstants.EXIT_ON_CLOSE);

        jPanel1.setBackground(new java.awt.Color(144, 56, 66));

        jLabel2.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        jLabel2.setForeground(new java.awt.Color(255, 255, 255));
        jLabel2.setText("Please insert the");

        jButton1.setBackground(new java.awt.Color(255, 255, 255));
        jButton1.setFont(new java.awt.Font("Montserrat", 0, 24)); // NOI18N
        jButton1.setText("Payment Complete");
        jButton1.setBorder(new javax.swing.border.LineBorder(new java.awt.Color(255, 255, 255), 1, true));
        jButton1.setBorderPainted(false);
        jButton1.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                jButton1ActionPerformed(evt);
            }
        });

        jLabel3.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        jLabel3.setForeground(new java.awt.Color(255, 255, 255));
        jLabel3.setText("terminal.");

        jLabel4.setFont(new java.awt.Font("Montserrat", 0, 36)); // NOI18N
        jLabel4.setForeground(new java.awt.Color(255, 255, 255));
        jLabel4.setText("card in the credit card");

        backBtn.setText("Back");
        backBtn.addActionListener(new java.awt.event.ActionListener() {
            public void actionPerformed(java.awt.event.ActionEvent evt) {
                backBtnActionPerformed(evt);
            }
        });

        javax.swing.GroupLayout jPanel1Layout = new javax.swing.GroupLayout(jPanel1);
        jPanel1.setLayout(jPanel1Layout);
        jPanel1Layout.setHorizontalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(24, 24, 24)
                        .addGroup(jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
                            .addComponent(jLabel4)
                            .addGroup(jPanel1Layout.createSequentialGroup()
                                .addGap(47, 47, 47)
                                .addComponent(jLabel2))
                            .addGroup(jPanel1Layout.createSequentialGroup()
                                .addGap(110, 110, 110)
                                .addComponent(jLabel3))))
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(188, 188, 188)
                        .addComponent(backBtn))
                    .addGroup(jPanel1Layout.createSequentialGroup()
                        .addGap(80, 80, 80)
                        .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 280, javax.swing.GroupLayout.PREFERRED_SIZE)))
                .addContainerGap(27, Short.MAX_VALUE))
        );
        jPanel1Layout.setVerticalGroup(
            jPanel1Layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(jPanel1Layout.createSequentialGroup()
                .addGap(48, 48, 48)
                .addComponent(jLabel2)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jLabel4)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(jLabel3)
                .addGap(31, 31, 31)
                .addComponent(jButton1, javax.swing.GroupLayout.PREFERRED_SIZE, 50, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addPreferredGap(javax.swing.LayoutStyle.ComponentPlacement.RELATED)
                .addComponent(backBtn)
                .addContainerGap(22, Short.MAX_VALUE))
        );

        javax.swing.GroupLayout layout = new javax.swing.GroupLayout(getContentPane());
        getContentPane().setLayout(layout);
        layout.setHorizontalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addComponent(jPanel1, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, Short.MAX_VALUE)
        );
        layout.setVerticalGroup(
            layout.createParallelGroup(javax.swing.GroupLayout.Alignment.LEADING)
            .addGroup(layout.createSequentialGroup()
                .addComponent(jPanel1, javax.swing.GroupLayout.PREFERRED_SIZE, javax.swing.GroupLayout.DEFAULT_SIZE, javax.swing.GroupLayout.PREFERRED_SIZE)
                .addGap(0, 0, Short.MAX_VALUE))
        );

        pack();
    }// </editor-fold>                        

    private void jButton1ActionPerformed(java.awt.event.ActionEvent evt) {                                         
        
        try{
            Class.forName("com.mysql.jdbc.Driver");
            Connection cn = DriverManager.getConnection("jdbc:mysql://remotemysql.com:3306/SlroZZ8W9B","SlroZZ8W9B","xEvUdzqfTW");
            
            String query="insert into ordertable(orderList, priceTotal, paymentMethod, crewInCharge) values(?,?,?,?)";
            PreparedStatement MyPst=cn.prepareStatement(query);
            MyPst.setString(1, orderListEntry);
            MyPst.setString(2, String.valueOf(totalAmountDue));
            MyPst.setString(3, "Card");
            MyPst.setString(4, crewName);

            MyPst.execute();
            MyPst.close();            
            cn.close();
            
        }catch(Exception e){            
            System.out.println(e.getMessage());            
        }
        
        new MainMenu(crewName).setVisible(true);
        dispose();
    }                                        

    private void backBtnActionPerformed(java.awt.event.ActionEvent evt) {                                        
        new MenuPageTabbed(crewName).setVisible(true);
        dispose();
    }                                       

    /**
     * @param args the command line arguments
     */
    public static void main(String args[]) {
        /* Set the Nimbus look and feel */
        //<editor-fold defaultstate="collapsed" desc=" Look and feel setting code (optional) ">
        /* If Nimbus (introduced in Java SE 6) is not available, stay with the default look and feel.
         * For details see http://download.oracle.com/javase/tutorial/uiswing/lookandfeel/plaf.html 
         */
        try {
            for (javax.swing.UIManager.LookAndFeelInfo info : javax.swing.UIManager.getInstalledLookAndFeels()) {
                if ("Nimbus".equals(info.getName())) {
                    javax.swing.UIManager.setLookAndFeel(info.getClassName());
                    break;
                }
            }
        } catch (ClassNotFoundException ex) {
            java.util.logging.Logger.getLogger(CardPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (InstantiationException ex) {
            java.util.logging.Logger.getLogger(CardPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (IllegalAccessException ex) {
            java.util.logging.Logger.getLogger(CardPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        } catch (javax.swing.UnsupportedLookAndFeelException ex) {
            java.util.logging.Logger.getLogger(CardPayment.class.getName()).log(java.util.logging.Level.SEVERE, null, ex);
        }
        //</editor-fold>
        //</editor-fold>

        /* Create and display the form */
        java.awt.EventQueue.invokeLater(new Runnable() {
            public void run() {
                new CardPayment().setVisible(true);
            }
        });
    }

    // Variables declaration - do not modify                     
    private javax.swing.JButton backBtn;
    private javax.swing.JButton jButton1;
    private javax.swing.JLabel jLabel2;
    private javax.swing.JLabel jLabel3;
    private javax.swing.JLabel jLabel4;
    private javax.swing.JPanel jPanel1;
    // End of variables declaration                   
}
